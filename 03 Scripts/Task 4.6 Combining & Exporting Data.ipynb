# %% [markdown]
# ### Task 4.6

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### Continuing on the first two questions answered in 'Notebook 4.6 Merging Instacart Data'
#
# ##### Import the orders_products_combined dataframe from the pickle file you just saved.

# %%
path = r'C:\Users\svand\Documents\01-02-2024 Instacart Basket Analysis'

# %%
df_merged_large = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ##### Check the shape of the imported dataframe (it should be the same as the one you exported.

# %%
df_merged_large.shape
# Out:
# (32640698, 12)

# %% [markdown]
# ##### Determine a suitable way to combine the orders_products_combined dataframe with your products data set.

# %%
df_prods_clean_no_dups = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %%
df_ords_prods_combined = df_merged_large

# %%
df_ords_prods_combined
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0                    0           0   2539329        1             1
# 1                    0           0   2539329        1             1
# 2                    0           0   2539329        1             1
# 3                    0           0   2539329        1             1
# 4                    0           0   2539329        1             1
# ...                ...         ...       ...      ...           ...
# 32640693       3421081     3421081   2977660   206209            13
# 32640694       3421081     3421081   2977660   206209            13
# 32640695       3421081     3421081   2977660   206209            13
# 32640696       3421081     3421081   2977660   206209            13
# 32640697       3421082     3421082    272231   206209            14
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                          2                  8                     NaN
# ...

# %%
df_prods_clean_no_dups.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 6)

# %%
# Getting rid of unnecessary columns:

df_prods_clean_no_dups = df_prods_clean_no_dups.drop(columns = ['Unnamed: 0'])

# %%
df_prods_clean_no_dups.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Getting rid of unnecessary columns:

df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0', '_merge'])

# %%
df_ords_prods_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN       196.0                1.0        0.0
# 1                     NaN     14084.0                2.0        0.0
# 2                     NaN     12427.0                3.0        0.0
# 3                     NaN     26088.0                4.0        0.0
# 4                     NaN     26405.0                5.0        0.0

# %%
df_ords_prods_merged = df_ords_prods_combined.merge(df_prods_clean_no_dups, on = 'product_id', indicator = True)

# %% [markdown]
# ##### As the product id is the matching column, I merged the dataframes on this. Als I got rid of the unneccesary columns to make the merged dataframe look more clean and clear

# %% [markdown]
# ##### Confirm the results of the merge using the merge flag.

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 14)

# %% [markdown]
# ##### Export the newly created dataframe as ords_prods_merge in a suitable format

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
